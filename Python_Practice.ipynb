# %% [markdown]
# <a href="https://colab.research.google.com/github/alokchoudharyguliya/Tensorflow-Practice/blob/main/Python_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Static methods
#   using `@staticmethod`

# %%
class Smiley():
  pass

# %% [markdown]
# Inheritance

# %%
class Smiley():
  upper_body=True
  def __init__(self,is_smile=True, face_color="white",eye_color="white",radius=5.0):
    self.is_smile=is_smile
    self.face_color=self.face_color
    self.eye_color=self.eye_color
    self.radius=self.radius

  @staticmethod
  def area(rad):
    return 3.14*(rad**2)

# %%
class SquareSmiley(Smiley):
