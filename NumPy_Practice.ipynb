# %% [markdown]
# <a href="https://colab.research.google.com/github/alokchoudharyguliya/Tensorflow-Practice/blob/main/NumPy_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - linspace
# - ones `np.ones()`
# - eye `np.eye()`
# - empty() `np.empty()`
# - random.random()
# - np.sort()
# - np.argsort()
# - np.reshape()
# - np.concatenate()

# %% [markdown]
# concept of axis -> 0 -> row, 1 -> column
